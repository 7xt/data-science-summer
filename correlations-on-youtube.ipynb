# %% [markdown]
# # Correlations On Youtube TOTW
#
# This notebook is to answer the task: Correlation between views and likes. This is my Third draft (content complete), I encourage constructive feedback. As time allows I will revisit this notebook and polish it up.
# The conclusion is that there is a strong positive correlation between views and likes on youtube.
#
#
# [US Data](#part-1)
#
# [World Data](#part-2)
#
# [Final Visual](#part-3)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <a id="part-1"></a>
# ## US Data
# We'll start with a subset of the data (US) before expanding to include the entire dataset

# %%
us_yt = pd.read_csv('../input/youtube-new/USvideos.csv')
display(us_yt.head())
print(us_yt.columns)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
#another curiousity of mine
us_yt.category_id.nunique()#.unique_count().sum()
# Out:
# 16

# %%
corrolation_list = ['views', 'likes', 'dislikes', 'comment_count']
hm_data = us_yt[corrolation_list].corr() 
display(hm_data)
#This will trim down the number of columns we are looking for correlations between
#this exceeds the scope of the initial question but i want to know a little more for myself
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849177  0.472213       0.617621
# likes          0.849177  1.000000  0.447186       0.803057
# dislikes       0.472213  0.447186  1.000000       0.700184
# comment_count  0.617621  0.803057  0.700184       1.000000

# %% [markdown]
# This is the pearson correlation values:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1 = a strong positive correlation<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 0 = no correlation<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; -1 = strong negative correlation.
#
# This shows that there is a strong positive correlation with number of likes and number of views, while there is a moderate correlation between views and comment count

# %%
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot

# %%
# to help you visualize these correlations, see the plots below
# the lighter the colour the higher the correlation

matplotlib.pyplot.figure(figsize=(8,6))
sns.heatmap(hm_data, annot=True);

# %%
#matplotlib.pyplot.figure(figsize=(12,12))
sns.pairplot(us_yt[['views', 'likes']], kind='reg',height=6);

# %%
#to get a closer look at the scatterplot for likes/views
matplotlib.pyplot.figure(figsize=(16,16))
sns.scatterplot(x=us_yt['views'], y=us_yt['likes']);

# %% [markdown]
# <a id="part-2"></a>
# ## World Data
#
# Now that we see the correlation coefficient for the US data, let's now see how much these trends stay the same in other countries.

# %%
#For these datasets we will use a subset of the columns, certain columns have characters that
#the dataframe can't currently handle and since those columns don't contain meaningful data for
#this use case I'm electing to simply drop them 
col_list = ['video_id', 'views', 'likes', 'dislikes', 'comment_count']

us_yt = pd.read_csv('../input/youtube-new/USvideos.csv', usecols=col_list) #USA, remaking the dataframe in the same format as the others
ca_yt = pd.read_csv('../input/youtube-new/CAvideos.csv', usecols=col_list) #Canada
de_yt = pd.read_csv('../input/youtube-new/DEvideos.csv', usecols=col_list) #Germany
fr_yt = pd.read_csv('../input/youtube-new/FRvideos.csv', usecols=col_list) #France
gb_yt = pd.read_csv('../input/youtube-new/GBvideos.csv', usecols=col_list) #United Kingdom (Great Brittain)
in_yt = pd.read_csv('../input/youtube-new/INvideos.csv', usecols=col_list) #India
jp_yt = pd.read_csv('../input/youtube-new/JPvideos.csv', usecols=col_list) #Japan
kr_yt = pd.read_csv('../input/youtube-new/KRvideos.csv', usecols=col_list) #South Korea
mx_yt = pd.read_csv('../input/youtube-new/MXvideos.csv', usecols=col_list) #Mexico
ru_yt = pd.read_csv('../input/youtube-new/RUvideos.csv', usecols=col_list) #Russia

# %%
df_list = [us_yt, ca_yt, de_yt, fr_yt, gb_yt, in_yt, jp_yt, kr_yt, mx_yt, ru_yt]
df_name_list = ['United States', 'Canada', 'Germany', 'France', 'Great Brittain', 'India',
                'Japan', 'South Korea', 'Mexico', 'Russia']

# %%
views_df = pd.DataFrame(columns=['views', 'likes', 'dislikes', 'comment_count'])
likes_df = pd.DataFrame(columns=['views', 'likes', 'dislikes', 'comment_count'])

display(views_df, likes_df)
# Out:
# Empty DataFrame
# Columns: [views, likes, dislikes, comment_count]
# Index: []
# Empty DataFrame
# Columns: [views, likes, dislikes, comment_count]
# Index: []

# %%
count = 0
while count != 10:
    print(df_name_list[count])
    current_df = df_list[count]
    _x = current_df[corrolation_list].corr()
    display(_x)
    views_df.loc[count] = _x.loc['views']
    likes_df.loc[count] = _x.loc['likes']
    count += 1
# Hid output to keep the size of the notebook down, feel free to unhide it to see more of the data
# Out:
# United States
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849177  0.472213       0.617621
# likes          0.849177  1.000000  0.447186       0.803057
# dislikes       0.472213  0.447186  1.000000       0.700184
# comment_count  0.617621  0.803057  0.700184       1.000000
# Canada
#                   views     likes  dislikes  comment_count
# views          1.000000  0.828964  0.557621       0.693107
# likes          0.828964  1.000000  0.460427       0.836585
# dislikes       0.557621  0.460427  1.000000       0.643494
# comment_count  0.693107  0.836585  0.643494       1.000000
# Germany
#                   views     likes  dislikes  comment_count
# views          1.000000  0.824189  0.556000       0.705516
# likes          0.824189  1.000000  0.460208       0.852492
# dislikes       0.556000  0.460208  1.000000       0.642144
# comment_count  0.705516  0.852492  0.642144       1.000000
# France
#                   views     likes  dislikes  comment_count
# views          1.000000  0.812569  0.586997       0.708161
# likes          0.812569  1.000000  0.450548       0.849647
# dislikes       0.586997  0.450548  1.000000       0.664893
# comment_count  0.708161  0.849647  0.664893       1.000000
# Great Brittain
#                   views     likes  dislikes  comment_count
# views          1.000000  0.795862  0.392407       0.466899
# likes          0.795862  1.000000  0.446746       0.744361
# dislikes       0.392407  0.446746  1.000000       0.771772
# comment_count  0.466899  0.744361  0.771772       1.000000
# India
#                   views     likes  dislikes  comment_count
# views          1.000000  0.850096  0.543294       0.674195
# likes          0.850096  1.000000  0.494560       0.780514
# dislikes       0.543294  0.494560  1.000000       0.708125
# comment_count  0.674195  0.780514  0.708125       1.000000
# Japan
#                   views     likes  dislikes  comment_count
# views          1.000000  0.850367  0.804670       0.843851
# likes          0.850367  1.000000  0.732570       0.940304
# dislikes       0.804670  0.732570  1.000000       0.809898
# comment_count  0.843851  0.940304  0.809898       1.000000
# South Korea
#                   views     likes  dislikes  comment_count
# views          1.000000  0.860043  0.581443       0.807600
# likes          0.860043  1.000000  0.428036       0.922731
# dislikes       0.581443  0.428036  1.000000       0.555549
# comment_count  0.807600  0.922731  0.555549       1.000000
# Mexico
#                   views     likes  dislikes  comment_count
# views          1.000000  0.798751  0.556964       0.677812
# likes          0.798751  1.000000  0.443179       0.845787
# dislikes       0.556964  0.443179  1.000000       0.634587
# comment_count  0.677812  0.845787  0.634587       1.000000
# Russia
#                   views     likes  dislikes  comment_count
# views          1.000000  0.820236  0.468503       0.732241
# likes          0.820236  1.000000  0.382125       0.845933
# dislikes       0.468503  0.382125  1.000000       0.487527
# comment_count  0.732241  0.845933  0.487527       1.000000

# %%
views_df = views_df.drop(axis=1, labels='views') #remove redundant column
views_df.index = df_name_list
display(views_df.style.background_gradient()) ## MasterData frame with all the correlation coefficients in relation to views
# Out:
# <style  type="text/css" >
#     #T_43bed64e_de90_11ea_b2c2_e1436656b542row0_col0 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row0_col1 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row0_col2 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row1_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row1_col1 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row1_col2 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row2_col0 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row2_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row2_col2 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row3_col0 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row3_col1 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row3_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row5_col0 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row5_col1 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row5_col2 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row6_col0 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row7_col1 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row7_col2 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row8_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row8_col1 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row8_col2 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row9_col0 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row9_col1 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_43bed64e_de90_11ea_b2c2_e1436656b542row9_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }</style><table id="T_43bed64e_de90_11ea_b2c2_e1436656b542" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >likes</th>        <th class="col_heading level0 col1" >dislikes</th>        <th class="col_heading level0 col2" >comment_count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row0_col0" class="data row0 col0" >0.849177</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row0_col1" class="data row0 col1" >0.472213</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row0_col2" class="data row0 col2" >0.617621</td>
#             </tr>
#             <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row1" class="row_heading level0 row1" >Canada</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row1_col0" class="data row1 col0" >0.828964</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row1_col1" class="data row1 col1" >0.557621</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row1_col2" class="data row1 col2" >0.693107</td>
#             </tr>
#             <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row2" class="row_heading level0 row2" >Germany</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row2_col0" class="data row2 col0" >0.824189</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row2_col1" class="data row2 col1" >0.556</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row2_col2" class="data row2 col2" >0.705516</td>
#             </tr>
#             <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row3" class="row_heading level0 row3" >France</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row3_col0" class="data row3 col0" >0.812569</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row3_col1" class="data row3 col1" >0.586997</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row3_col2" class="data row3 col2" >0.708161</td>
#             </tr>
#             <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row4" class="row_heading level0 row4" >Great Brittain</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row4_col0" class="data row4 col0" >0.795862</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row4_col1" class="data row4 col1" >0.392407</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row4_col2" class="data row4 col2" >0.466899</td>
#             </tr>
#             <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row5" class="row_heading level0 row5" >India</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row5_col0" class="data row5 col0" >0.850096</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row5_col1" class="data row5 col1" >0.543294</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row5_col2" class="data row5 col2" >0.674195</td>
#             </tr>
#             <tr>
#                         <th id="T_43bed64e_de90_11ea_b2c2_e1436656b542level0_row6" class="row_heading level0 row6" >Japan</th>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row6_col0" class="data row6 col0" >0.850367</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row6_col1" class="data row6 col1" >0.80467</td>
#                         <td id="T_43bed64e_de90_11ea_b2c2_e1436656b542row6_col2" class="data row6 col2" >0.843851</td>
#             </tr>
#             <tr

# %%
likes_df = likes_df.drop(axis=1, labels='likes') #remove redundant column
likes_df.index = df_name_list
display(likes_df.style.background_gradient()) ## Master Data frame with all the corrolation coefficients in relation to likes
# Out:
# <style  type="text/css" >
#     #T_43c5a32a_de90_11ea_b2c2_e1436656b542row0_col0 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row0_col1 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row0_col2 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row1_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row1_col1 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row1_col2 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row2_col0 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row2_col1 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row2_col2 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row3_col0 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row3_col1 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row3_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row4_col1 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row5_col0 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row5_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row5_col2 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row6_col0 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row7_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row7_col2 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row8_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row8_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row8_col2 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row9_col0 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_43c5a32a_de90_11ea_b2c2_e1436656b542row9_col2 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }</style><table id="T_43c5a32a_de90_11ea_b2c2_e1436656b542" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >views</th>        <th class="col_heading level0 col1" >dislikes</th>        <th class="col_heading level0 col2" >comment_count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row0_col0" class="data row0 col0" >0.849177</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row0_col1" class="data row0 col1" >0.447186</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row0_col2" class="data row0 col2" >0.803057</td>
#             </tr>
#             <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row1" class="row_heading level0 row1" >Canada</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row1_col0" class="data row1 col0" >0.828964</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row1_col1" class="data row1 col1" >0.460427</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row1_col2" class="data row1 col2" >0.836585</td>
#             </tr>
#             <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row2" class="row_heading level0 row2" >Germany</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row2_col0" class="data row2 col0" >0.824189</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row2_col1" class="data row2 col1" >0.460208</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row2_col2" class="data row2 col2" >0.852492</td>
#             </tr>
#             <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row3" class="row_heading level0 row3" >France</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row3_col0" class="data row3 col0" >0.812569</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row3_col1" class="data row3 col1" >0.450548</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row3_col2" class="data row3 col2" >0.849647</td>
#             </tr>
#             <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row4" class="row_heading level0 row4" >Great Brittain</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row4_col0" class="data row4 col0" >0.795862</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row4_col1" class="data row4 col1" >0.446746</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row4_col2" class="data row4 col2" >0.744361</td>
#             </tr>
#             <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row5" class="row_heading level0 row5" >India</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row5_col0" class="data row5 col0" >0.850096</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row5_col1" class="data row5 col1" >0.49456</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row5_col2" class="data row5 col2" >0.780514</td>
#             </tr>
#             <tr>
#                         <th id="T_43c5a32a_de90_11ea_b2c2_e1436656b542level0_row6" class="row_heading level0 row6" >Japan</th>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row6_col0" class="data row6 col0" >0.850367</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row6_col1" class="data row6 col1" >0.73257</td>
#                         <td id="T_43c5a32a_de90_11ea_b2c2_e1436656b542row6_col2" class="data row6 col2" >0.940304</td>
#             </tr>
#             <

# %%
matplotlib.pyplot.figure(figsize=(8,6))
sns.heatmap(likes_df, annot=True, linewidths=.5);

# %% [markdown]
# We can see that there is a high correlation between the number of likes on a video and the number of views. Also an interesting note: likes and comment count has an incredibly high correlation in Japan, Japan also has a weirdly high correlation between dislikes, likes and views (one could also rephrase this to a high correlation between reactions and views). There are other interesting little tidbits in the data.
#
# (obligatory correlation =/= causation speil)Without seeing this data in timelapse one couldn't determine if a particular variable is the cause of the other. For instance: are videos that are watched frequently more likely to be liked by a viewer, or does a video receiving a large number of likes cause it to be recommended frequently. Or perhaps neither is the cause of the other and perhaps some confounding variable is the cause of both of these.

# %%
Master_df = pd.DataFrame(columns=['views', 'likes', 'dislikes', 'comment_count', 'country'])
display(Master_df)
# Out:
# Empty DataFrame
# Columns: [views, likes, dislikes, comment_count, country]
# Index: []

# %%
#now to create a master dataframe with all the datapoints in it
count = 0
entries = 0
while count != 10:
    current_df = df_list[count]
    entries = entries + len(current_df)
    country_name = df_name_list[count]
    current_df['country'] = country_name
    Master_df = pd.merge(Master_df, current_df, how='outer')
    count += 1
print(entries)
# Out:
# 375942

# %%
print(entries) 
print(len(Master_df)) #comparing the total number of entries to make sure I didn't lose any data points 
display(Master_df.sample(10))
# Out:
# 375942
# 375942
#            video_id    views   likes  dislikes  comment_count         country
# 410     _BVAJ3PXZ1k   533940   12633       597           1828   United States
# 332293  xTlNMmZKwpA  8227432  631427     21807          48184          Mexico
# 44328   uzup2wh-0V4   102263    1698        42             31          Canada
# 63614   WCeUjXhQ7FU   166887    2988       243            356          Canada
# 304384  Kebmpdp9pXA   180553   12455       437            956          Mexico
# 48386   QvjC2JMhvF0   157375    6206       119           1105          Canada
# 174067  nranUeNkXpM  3999438  104009      6930           8495  Great Brittain
# 106153  bhK7thf73G4    49750    6073       103           1154         Germany
# 343237  7zdJTk6TpAU   427955   27115      1523           2526          Russia
# 83700   cHB_s970Uyw  1980168   77376      1955           9955         Germany

# %%
Master_df[corrolation_list].corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col1 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col0 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col3 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col3 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col1 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col2 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_4597c37c_de90_11ea_b2c2_e1436656b542" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >views</th>        <th class="col_heading level0 col1" >likes</th>        <th class="col_heading level0 col2" >dislikes</th>        <th class="col_heading level0 col3" >comment_count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4597c37c_de90_11ea_b2c2_e1436656b542level0_row0" class="row_heading level0 row0" >views</th>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col1" class="data row0 col1" >0.777796</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col2" class="data row0 col2" >0.421653</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row0_col3" class="data row0 col3" >0.51003</td>
#             </tr>
#             <tr>
#                         <th id="T_4597c37c_de90_11ea_b2c2_e1436656b542level0_row1" class="row_heading level0 row1" >likes</th>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col0" class="data row1 col0" >0.777796</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col2" class="data row1 col2" >0.45371</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row1_col3" class="data row1 col3" >0.79449</td>
#             </tr>
#             <tr>
#                         <th id="T_4597c37c_de90_11ea_b2c2_e1436656b542level0_row2" class="row_heading level0 row2" >dislikes</th>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col0" class="data row2 col0" >0.421653</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col1" class="data row2 col1" >0.45371</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row2_col3" class="data row2 col3" >0.705182</td>
#             </tr>
#             <tr>
#                         <th id="T_4597c37c_de90_11ea_b2c2_e1436656b542level0_row3" class="row_heading level0 row3" >comment_count</th>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col0" class="data row3 col0" >0.51003</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col1" class="data row3 col1" >0.79449</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col2" class="data row3 col2" >0.705182</td>
#                         <td id="T_4597c37c_de90_11ea_b2c2_e1436656b542row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <a id="part-3"></a>
# ## Final Visual
#
# As you can see below the trend below seems to follow for each country in the datasets

# %%
matplotlib.pyplot.figure(figsize=(16,16))
sns.scatterplot(x=Master_df["views"], y=Master_df["likes"], hue=Master_df["country"])
sns.despine(bottom=True, left=True);

# %% [markdown]
# # Final Thoughts
# There is a strong positive correlation between likes and views. This trend is more visible in outlier cases.
#
#
# This year I've challenged myself to complete one task on Kaggle per week, in order to develop a larger Data Science portfolio. If you found this notebook useful or interesting please give it an upvote. If you would like to collaborate on a future task of the week feel free to leave a comment here or message me directly. For past TOTW check out the link to my page on github for this ongoing project https://github.com/Neil-Kloper/Weekly-Kaggle-Task/wiki
